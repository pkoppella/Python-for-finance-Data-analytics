# %%
import numpy
import pandas
import matplotlib
import random
import statsmodels

# %%
import numpy as np
a = np.array([[0,1,2,3],[4,5,6,7]])
a
# Out:
# array([[0, 1, 2, 3],
#        [4, 5, 6, 7]])

# %%
a[1]
# Out:
# array([4, 5, 6, 7])

# %%
import random
number = random.randint(1,6)
number
# Out:
# 6

# %%
np.random.randint(1,89,(4,4))
# Out:
# array([[52, 26, 29, 14],
#        [46, 76, 58, 31],
#        [72, 72, 75, 11],
#        [61, 48, 84, 87]])

# %%
import pandas as pd
ser = pd.Series(np.random.random(5), name='col1')
ser
s = pd.Series([1,np.nan,3],type= date,name = 'col0')
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-47d81d773e43> in <module>()
#       2 ser = pd.Series(np.random.random(5), name='col1')
#       3 ser
# ----> 4 s = pd.Series([1,np.nan,3],type= date,name = 'col0')
#       5 s
#
# NameError: name 'date' is not defined

# %%
import pandas_datareader
from pandas_datareader import data as wb
PG = wb.DataReader('PG', data_source = 'google')
PG
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2010-01-04  61.11  61.31  60.63  61.12   9190873
# 2010-01-05  61.13  61.28  60.60  61.14   8650514
# 2010-01-06  60.94  60.96  60.50  60.85   9908909
# 2010-01-07  60.58  60.70  60.24  60.52   8972748
# 2010-01-08  60.36  60.53  60.06  60.44   8466961
# 2010-01-11  60.08  60.27  59.01  60.20  14775303
# 2010-01-12  60.70  61.36  60.50  60.89  13461316
# 2010-01-13  61.04  61.79  60.91  61.52  16968809
# 2010-01-14  61.42  61.74  61.38  61.58   9139454
# 2010-01-15  61.60  61.86  60.44  60.82  15769766
# 2010-01-19  60.80  61.83  60.80  61.72  11577895
# 2010-01-20  60.97  61.04  60.10  60.45  11557958
# 2010-01-21  60.56  60.93  59.45  59.84  14300131
# 2010-01-22  59.75  60.69  59.22  60.31  17703177
# 2010-01-25  60.83  60.98  60.15  60.63  11631216
# 2010-01-26  60.17  60.95  60.00  60.69  13079472
# 2010-01-27  60.46  60.98  59.95  60.81  15228937
# 2010-01-28  61.67  63.31  61.58  61.68  26931270
# ...

# %%
PG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1905 entries, 2010-01-04 to 2017-07-27
# Data columns (total 5 columns):
# Open      1905 non-null float64
# High      1905 non-null float64
# Low       1905 non-null float64
# Close     1905 non-null float64
# Volume    1905 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 89.3 KB

# %%
PG.head(20)
# Out:
#              Open   High    Low  Close    Volume
# Date
# 2001-08-28  38.12  38.24  37.40  37.50   7206200
# 2001-08-29  37.80  37.80  36.90  37.01   5262400
# 2001-08-30  37.08  37.55  36.98  37.30   7104200
# 2001-08-31  36.90  37.18  36.82  37.08   4653200
# 2001-09-04  36.84  38.04  36.84  37.76   7429000
# 2001-09-05  37.76  38.12  37.45  37.94   7687200
# 2001-09-06  37.94  38.00  37.36  37.75   8744400
# 2001-09-07  37.45  37.60  36.70  37.18   6475200
# 2001-09-10  36.72  37.20  36.65  37.10   7404800
# 2001-09-17  36.80  37.45  36.25  37.28  11837800
# 2001-09-18  37.05  37.12  36.64  37.10   9209000
# 2001-09-19  37.32  37.51  36.62  37.28  11089400
# 2001-09-20  37.00  37.00  36.28  36.40   9654200
# 2001-09-21  35.32  35.82  33.00  33.50  20098200
# 2001-09-24  34.50  35.22  34.44  34.73  10251600
# 2001-09-25  34.73  35.60  34.72  35.50   7980800
# 2001-09-26  35.85  36.12  35.40  35.56   6894000
# 2001-09-27  35.75  36.20  35.53  36.20   7136200
# ...

# %%
tickers = ['PG','MSFT','GE','T','F']
new_data = pd.DataFrame()
for t in tickers:
    new_data[t] = wb.DataReader(t, data_source = 'google', start='1995-1-1')['Close']

# %%
new_data.head()
# Out:
#                PG   MSFT     GE      T      F
# Date
# 2001-08-31  37.08  28.53  40.98  40.91  19.87
# 2001-09-04  37.76  28.05  40.83  42.00  20.25
# 2001-09-05  37.94  28.87  41.70  42.24  19.97
# 2001-09-06  37.75  28.01  40.50  41.90  19.40
# 2001-09-07  37.18  27.70  39.66  41.00  18.76

# %%
import quandl

# %%
mydata_01 = quandl.get("FRED/GDP")

# %%
import matplotlib.pyplot as plt
import sys #only needed to determine Python version number
import matplotlib
mydata_01.plot()
plt.show()

# %%
import pandas as pd

# %%
mydata_01.to_csv('/Users/rgottumukkal/jobs/example01.csv')

# %%
mydata_02 = pd.read_csv('/Users/rgottumukkal/jobs/banklist.csv')

# %%
mydata_02.tail()
# Out:
#                              Bank Name        City  ST   CERT  \
# 548                 Superior Bank, FSB    Hinsdale  IL  32646
# 549                Malta National Bank       Malta  OH   6629
# 550    First Alliance Bank & Trust Co.  Manchester  NH  34264
# 551  National State Bank of Metropolis  Metropolis  IL   3815
# 552                   Bank of Honolulu    Honolulu  HI  21029
#
#                    Acquiring Institution Closing Date Updated Date
# 548                Superior Federal, FSB    27-Jul-01    19-Aug-14
# 549                    North Valley Bank     3-May-01    18-Nov-02
# 550  Southern New Hampshire Bank & Trust     2-Feb-01    18-Feb-03
# 551              Banterra Bank of Marion    14-Dec-00    17-Mar-05
# 552                   Bank of the Orient    13-Oct-00    17-Mar-05
