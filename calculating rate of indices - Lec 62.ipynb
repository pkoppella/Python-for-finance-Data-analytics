# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/Users/rgottumukkal/Downloads/Indices-Data-1.csv", index_col='Date')

# %%
data.tail(4)
# Out:
#                   ^GSPC        ^IXIC       ^GDAXI
# Date
# 20/03/2017  2373.469971  5901.529785  12052.90039
# 21/03/2017  2344.020020  5793.830078  11962.12988
# 22/03/2017  2348.449951  5821.640137  11904.12012
# 23/03/2017  2345.959961  5817.689941  12039.67969

# %%
(data/data.iloc[0]*100).plot(figsize=(10,8));
plt.show()

# %%
ind_returns = (data/data.shift(1))- 1
ind_returns.head()
# Out:
#                ^GSPC     ^IXIC    ^GDAXI
# Date
# 02/01/1997       NaN       NaN       NaN
# 03/01/1997  0.014952  0.023409  0.003686
# 06/01/1997 -0.000508  0.004364  0.007694
# 07/01/1997  0.007463  0.008607  0.001666
# 08/01/1997 -0.006399 -0.005558  0.006999

# %%
annual_ind_returns = ind_returns.mean()*250
annual_ind_returns
# Out:
# ^GSPC     0.075836
# ^IXIC     0.107076
# ^GDAXI    0.100426
# dtype: float64

# %%
data2 = pd.read_csv("/Users/rgottumukkal/Downloads/Indices-Data-2.csv", index_col='Date')
data2.head()
# Out:
#                    PG        ^GSPC         ^DJI
# Date
# 2007-01-03  64.540001  1416.599976  12474.51953
# 2007-01-04  64.050003  1418.339966  12480.69043
# 2007-01-05  63.500000  1409.709961  12398.00977
# 2007-01-08  63.639999  1412.839966  12423.49023
# 2007-01-09  63.480000  1412.109985  12416.59961

# %%
(data2/data2.iloc[0]*100).plot(figsize=(10,8));
plt.show()

# %%
ind_returns_2 = (data2/data2.shift(1))-1
annual_ind_returns_2 = ind_returns_2.mean()*250
annual_ind_returns_2
# Out:
# PG       0.048893
# ^GSPC    0.070342
# ^DJI     0.066991
# dtype: float64

# %%
annual_ind_returns_2.plot(figsize=(2,2));
plt.show()
